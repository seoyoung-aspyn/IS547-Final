# %%
import pandas as pd
import numpy as np
import re
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import gensim.downloader as api
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/seoyoungyoon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/seoyoungyoon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
relevancy_scores = pd.read_csv("relevancy_scores.csv")
relevant_docs = pd.read_csv("relevant_document_list.csv")

# %%
relevancy_scores.head()
# Out:
#    internal_id                                           keywords  \
# 0     40941026  Hydrogen Fuel Cells|Alkaline Fuel Cells|Fuel C...
# 1     40941027              Detonation-to-Deflagration Transition
# 2     40941028  PEM Fuel Cells|Battery Management Systems|Hydr...
# 3     40941029  Power Management Strategy|Battery Life Optimiz...
# 4     40941030       Battery Life Optimization|Battery Technology
#
#                                             abstract  \
# 0  This paper presents the experimental results o...
# 1  Lithium-ion batteries (LIBs) have been widely ...
# 2                                                NaN
# 3  The Energy Management Strategy (EMS) in Fuel C...
# 4  Currently, major vehicle manufacturers are wor...
#
#                                                title  manual_screen_score  \
# 0  An actively controlled fuel cell/battery hybri...                  1.0
# 1  Characterization of the deflagration behavior ...                 -1.0
# 2  Intelligent Control Strategy for Energy Manage...                 -1.0
# 3  Multi-Objective Optimization-Based Health-Cons...                  1.0
# 4  The choice of a performance criterion for a hi...                  1.0
#
#    relevancy  predicted_screen_score
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN

# %%
relevant_docs.head()
# Out:
#    (internal) id           (source) id  \
# 0       40941026  https://openalex.org
# 1       40941029  https://openalex.org
# 2       40941030  https://openalex.org
# 3       40941032  https://openalex.org
# 4       40941035  https://openalex.org
#
#                                             keywords  \
# 0  Hydrogen Fuel Cells|Alkaline Fuel Cells|Fuel C...
# 1  Power Management Strategy|Battery Life Optimiz...
# 2       Battery Life Optimization|Battery Technology
# 3                                 Battery Technology
# 4  PEM Fuel Cells|Hydrogen Fuel Cells|Fuel Cell D...
#
#                                             abstract  \
# 0  This paper presents the experimental results o...
# 1  The Energy Management Strategy (EMS) in Fuel C...
# 2  Currently, major vehicle manufacturers are wor...
# 3  Battery electric vehicles (BEVs) and fuel cell...
# 4  This paper develops a proton exchange membrane...
#
#                                                title  \
# 0  An actively controlled fuel cell/battery hybri...
# 1  Multi-Objective Optimization-Based Health-Cons...
# 2  The choice of a performance criterion for a hi...
# 3  A comparative assessment of battery and fuel c...
# 4  Cost analyses and optimization of a PEMFC elec...
#
#                                              journal  \
# 0                           Journal of power sources
# 1                                           Energies
# 2  IOP conference series. Materials science and e...
# 3                                             Energy
# 4                                                NaN
#
#                                              authors  \
# 0            Lijun Gao|Zhenhua Jiang|Roger A. Dougal
# 1  Mehdi Sellali|Alexandre Ravey|Achour Betka|Abd...
# 2                       I. A. Lyubimov|Р. Х. Курмаев
# 3                 Mengyu Li|Xiongwen Zhang|Guojun Li
# 4                         Yu-Ting Teng|Fu-Cheng Wang
#
#                                               doi
# 0  https://doi.org/10.1016/j.jpowsour.2003.12.052
# 1              https://doi.org/10.3390/en15041318
# 2  https://doi.org/10.1088/1757-899x/819/1/012015
# 3    https://doi.org/10.1016/j.energy.2015.11.023
# 4        https://doi.org/10.1109/sii.2016.7844112

# %% [markdown]
# ## Data Cleaning

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    if pd.isnull(text):
        return ""
    text = str(text).lower()
    text = re.sub(r"\?\?\?", "", text)
    text = re.sub(r"\[\]|\(\)", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\bev\b", "electric vehicle", text)
    text = re.sub(r"\bli[\-\s]?ion\b", "lithium ion", text)
    text = re.sub(r"\bh2\b", "hydrogen", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
relevant_docs['clean_abstract'] = relevant_docs['abstract'].apply(clean_text)
relevant_docs['clean_title'] = relevant_docs['title'].apply(clean_text)

# Remove missing rows
relevant_docs.dropna(subset=['abstract', 'title'], inplace=True)

# %%
# DOI validity check
relevant_docs['valid_doi'] = relevant_docs['doi'].apply(lambda x: isinstance(x, str) and x.startswith('https://doi.org/10.'))
invalid_dois = relevant_docs[~relevant_docs['valid_doi']]
print(f"Invalid DOIs found: {len(invalid_dois)}")
# Out:
# Invalid DOIs found: 0

# %%
relevant_docs.reset_index(drop=True, inplace=True)

# %%
relevant_docs
# Out:
#      (internal) id           (source) id  \
# 0         40941026  https://openalex.org
# 1         40941029  https://openalex.org
# 2         40941030  https://openalex.org
# 3         40941032  https://openalex.org
# 4         40941035  https://openalex.org
# ..             ...                   ...
# 152       40941317  https://openalex.org
# 153       40941318  https://openalex.org
# 154       40941320  https://openalex.org
# 155       40941321  https://openalex.org
# 156       40941323  https://openalex.org
#
#                                               keywords  \
# 0    Hydrogen Fuel Cells|Alkaline Fuel Cells|Fuel C...
# 1    Power Management Strategy|Battery Life Optimiz...
# 2         Battery Life Optimization|Battery Technology
# 3                                   Battery Technology
# 4    PEM Fuel Cells|Hydrogen Fuel Cells|Fuel Cell D...
# ..                                                 ...
# 152  Battery Technology|Electric Vehicles|Battery M...
# 153  Fuel Cell Vehicles|Battery Life Optimization|B...
# 154  Power Management Strategy|Battery Life Optimiz...
# 155  Power Management Strategy|Battery Life Optimiz...
# 156  PEM Fuel Cells|Fuel Cell Durability|Hydrogen F...
#
#                                               abstract  \
# 0    This paper presents the experimental results o...
# 1    The Energy Management Strategy (EMS) in Fuel C...
# 2    Currently, major vehicle manufacturers are wor...
# 3    Battery electric vehicles (BEVs) and fuel cell...
# 4    This paper develops a proton exchange membrane...
# ..                                                 ...
# 152  This chapter focuses on the battery electric v...
# 153  Sometimes technology and development of societ...
# 154  The use of multi-stack fuel cells (FCs) is att...
# 155  This paper focus on offline energy management ...
# 156  Under the background of energy and environment...
#
#                                                  title  \
# 0    An actively controlled fuel cell/battery hybri...
# 1    Multi-Objective Optimization-Based Health-Cons...
# 2    The choice of a performance criterion for a hi...
# 3    A comparative assessment of battery and fuel c...
# 4    Cost analyses and optimization of a PEMFC elec...
# ..                                                 ...
# 152             The Case for Battery Electric Vehicles
# 153  A new approach to battery powered electric veh...
# 154  Q-learning based energy management strategy fo...
# 155  Hybrid Systems Energy Management Using Optimiz...
# 156  Design of energy and materials for ammonia-bas...
#
#                                                journal  \
# 0                             Journal of power sources
# 1                                             Energies
# 2    IOP conference series. Materials science and e...
# 3                                               Energy
# 4                                                  NaN
# ..                                                 ...
# 152                                    Elsevier eBooks
# 153           International journal of hydrogen energy
# 154                   Energy conversion and management
# 155                                                NaN
# 156                                    Energy procedia
#
#                                                authors  \
# 0              Lijun Gao|Zhenhua Jiang|Roger A. Dougal
# 1    Mehdi Sellali|Alexandre Ravey|Achour Betka|Abd...
# 2                         I. A. Lyubimov|Р. Х. Курмаев
# 3                   Mengyu Li|Xiongwen Zhang|Guojun Li
# 4                           Yu-Ting Teng|Fu-Cheng Wang
# ..                                                 ...
# 152                                     Paul Maccready
# 153  Roberto Álvarez Fernández|Fernando Beltrán Cil...
# 154  Razieh Ghaderi|Mohsen Kandidayeni|Loïc Boulon|...
# 155  Yacine Gaoua|Stéphane Caux|Pierre López|C. Rag...
# 156  Yuchu Chu|Yihan Wu|Jin Chen|Songsheng Zheng|Zh...
#
#                                                   doi  \
# 0      https://doi.org/10.1016/j.jpowsour.2003.12.052
# 1                  https://doi.org/10.3390/en15041318
# 2      https://doi.org/10.1088/1757-899x/819/1/012015
# 3        https://doi.org/10.1016/j.energy.2015.11.023
# 4            https://doi.org/10.1109/sii.2016.7844112
# ..                                                ...
# 152  https://doi.org/10.1016/b978-012656881-3/50016-2
# 153    https://doi.org/10.1016/j.ijhydene.2016.01.035
# 154    https://doi.org/10.1016/j.enconman.2023.117524
# 155         https://doi.org/10.1109/vppc.2014.7007079
# 156      https://doi.org/10.1016/j.egypro.2019.01.991
#
#                                         clean_abstract  \
# 0    this paper presents the experimental results o...
# 1    the energy management strategy ems in fuel cel...
# 2    currently major vehicle manufacturers are work...
# 3    battery electric vehicles bevs and fuel cell e...
# 4    this paper develops a proton exchange membrane...
# ..                                                 ...
# 152  this chapter focuses on the battery electric v...
# 153  sometimes technology and development of societ...
# 154  the use of multistack fuel cells fcs is attrac...
# 155  this paper focus on offline energy management ...
# 156  under the background of energy and environment...
#
#                                            clean_title  valid_doi
# 0    an actively controlled fuel cellbattery hybrid...       True
# 1    multiobjective optimizationbased healthconscio...       True
# 2    the choice of a performance criterion for a hi...       True
# 3    a comparative assessment of battery and fuel c...       True
# 4    cost analyses and optimization of a pemfc elec...       True
# ..                                                 ...        ...
# 152             the case for battery electric vehicles       True
# 153  a new approach to battery powered electric veh...       True
# 154  qlearning based energy management strategy for...       True
# 155  hybrid systems energy management using optimiz...       True
# 156  design of energy and materials for ammoniabase...       True
#
# [157 rows x 11 columns]

# %% [markdown]
# ## TF-IDF RELEVANCE SCORING

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
doc_vectors = tfidf_vectorizer.fit_transform(relevant_docs['clean_abstract'])

query = "electric vehicle battery hydrogen lithium ion"
query_vector = tfidf_vectorizer.transform([query])

cos_sim = cosine_similarity(query_vector, doc_vectors).flatten()
relevant_docs['tfidf_score'] = cos_sim

# %%
relevant_docs['tfidf_score']
# Out:
# 0      0.020184
# 1      0.026052
# 2      0.068523
# 3      0.019536
# 4      0.056160
#          ...
# 152    0.188996
# 153    0.075232
# 154    0.034895
# 155    0.037864
# 156    0.085464
# Name: tfidf_score, Length: 157, dtype: float64

# %%
relevant_docs.to_csv('cleaned_relevant_docs.csv')

# %% [markdown]
# ## Word-to-vec scoring
